# %%
#import telepot
import telebot

from telebot import types 


#token = '1897188934:AAFelbaJ1eSNfSG1-EHsX42TLbf2_Ot1t60'
#bot = telepot.Bot(token)

main1

bot = telebot.TeleBot('1897188934:AAFelbaJ1eSNfSG1-EHsX42TLbf2_Ot1t60');
#print(telegramBot.getMe())
#telegramBot.getUpdates()
#telegramBot.getUpdates(598304315)
#@bot.message_handler(content_types=['text'])
#@bot.message_handler(commands=['start'])
##def start(message):
#    bot.send_message(message.chat.id, 'Привет Ритуля!')



@bot.message_handler(commands=['start'])
#def send_welcome(message):
#    bot.reply_to(message, "Что для Вас приготовить?") 

def start(message):

#  def send_welcome(message):
  #bot.reply_to(message, "Что для Вас приготовить?") 
  markup = types.ReplyKeyboardMarkup()
  buttonA = types.KeyboardButton('Кофе')
  buttonB = types.KeyboardButton('Чай')
  buttonC = types.KeyboardButton('Другое')
    
  markup.row(buttonA)
  markup.row(buttonB)
  markup.row(buttonC)

  bot.send_message(message.chat.id, 'Что для Вас приготовить? Выберите напиток', reply_markup=markup)    
 edit_message_reply_markup
 
@bot.message_handler(func=lambda message: True)
def echo_all(message):
    print(message.text)
 
    if message.text=="Кофе":
        markup2 = types.ReplyKeyboardMarkup()
        itembtn1 = types.KeyboardButton('Капучино')
        itembtn2 = types.KeyboardButton('Американо')
        itembtn3 = types.KeyboardButton('Эспрессо')
        
        markup2.add(itembtn1)
        markup2.add(itembtn2)
        markup2.add(itembtn3)
        
    elif message.text=="чай":
        markup2 = types.ReplyKeyboardMarkup()
        itembtn1 = types.KeyboardButton('облепиха')
        itembtn2 = types.KeyboardButton('смородина')
        itembtn3 = types.KeyboardButton('классика')
        
        markup2.add(itembtn1)
        markup2.add(itembtn2)
        markup2.add(itembtn3)

        bot.send_message(message.chat.id, "выберите кофе", reply_markup=markup2)
       
@bot.message_handler(func=lambda message: True)
def echo_all(message):
    print(message.text)
    
    if message.text=="Капучино":
            markup21 = types.ReplyKeyboardMarkup()
            itembtn11 = types.KeyboardButton('0.3')
            itembtn21 = types.KeyboardButton('0.4')
        
            markup2.add(itembtn11)
            markup2.add(itembtn21)

            bot.send_message(message.chat.id, "выберите объем", reply_markup=markup21)
        
@bot.message_handler(func=lambda message: True)
def echo_all(message):
    print(message.text) 
    print("ffffffff")
    if message.text=="0.3":
            markup2 = types.ReplyKeyboardMarkup()
            itembtn111 = types.KeyboardButton('сироп 1')
            itembtn211 = types.KeyboardButton('сироп 2')
            markup2.add(itembtn111)
            markup2.add(itembtn211)
            bot.send_message(message.chat.id, "выберите добавку", reply_markup=markup2)
            
            
        
        
        
        
        
        
        
        
        
"""        
    else:
        markup = types.ReplyKeyboardMarkup()
        itembtn1 = types.KeyboardButton('Первая кнопка')
        markup.add(itembtn1)
        bot.send_message(message.chat.id, "Присылаю первую кнопку", reply_markup=markup)
"""
 
bot.polling()

# %%
def despaired_person():
    print('here1')
    yield None
    print('here2')
    yield None
    print('here3')
    yield None
    print('here4')
    return "I'm tired of my uselessness"
print('here5')
# Out:
# here5

# %%
"""import telebot
telegramBot.getUpdates()

@bot.message_handler(commands=['start'])
def start(message):
  markup = types.ReplyKeyboardMarkup()
  buttonA = types.KeyboardButton('Кофе')
  buttonB = types.KeyboardButton('Чай')
  buttonC = types.KeyboardButton('Другое')
    
  markup.row(buttonA)
  markup.row(buttonB)
  markup.row(buttonC)

  bot.send_message(message.chat.id, 'Выберите напиток', reply_markup=markup)

if massage.text


bot.polling()



@bot.message_handler(commands=['start2', 'help'])
def send_welcome(message):
    bot.reply_to(message, "Howdy, how are you doing?") 

@bot.message_handler(content_types=["text"])
def default_test(message):
    keyboard = types.InlineKeyboardMarkup()
    url_button = types.InlineKeyboardButton(text="Перейти на Яндекс", url="https://ya.ru")
    keyboard.add(url_button)
    bot.send_message(message.chat.id, "Привет! Нажми на кнопку и перейди в поисковик.", reply_markup=keyboard)
  

    
@bot.message_handler(commands = ['switch'])
def switch(message):
    markup = types.InlineKeyboardMarkup()
    switch_button = types.InlineKeyboardButton(text='Try', switch_inline_query="Telegram")
    markup.add(switch_button)
    bot.send_message(message.chat.id, "Выбрать чат", reply_markup = markup)
    
    
    
    @bot.message_handler(commands = ['url'])
def url(message):
    markup = types.InlineKeyboardMarkup()
    btn_my_site= types.InlineKeyboardButton(text='Наш сайт', url='https://habrahabr.ru')
    markup.add(btn_my_site)
    bot.send_message(message.chat.id, "Нажми на кнопку и перейди на наш сайт.", reply_markup = markup) 

    
    
    
    #def start_message(message):
#    bot.send_message(message.chat.id, 'Пришли мне Emoji, который необходимо сделать размытым.')

#def get_text_messages(message):
#    if message.text == "Привет":
#        bot.send_message(message.from_user.id, "Привет, чем я могу тебе помочь?")
#    elif message.text == "/help":
#        bot.send_message(message.from_user.id, "Напиши привет")
#    else:
#      bot.send_message(message.from_user.id, "Я тебя не понимаю. Напиши /help.")
"""

# %%
#help (types.ReplyKeyboardMarkup())
